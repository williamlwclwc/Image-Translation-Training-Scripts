# %%
# !nvidia-smi
# Out:
# Tue Mar 17 11:52:17 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.59       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip /content/drive/'My Drive'/3rd-year-project/freiburg-forest.zip
# Out:
# Archive:  /content/drive/My Drive/3rd-year-project/freiburg-forest.zip
#    creating: freiburg-forest/
#    creating: freiburg-forest/train/
#    creating: freiburg-forest/train/GT_color/
#   inflating: freiburg-forest/train/GT_color/b290-499_mask.png
#   inflating: freiburg-forest/train/GT_color/b457-708_mask.png
#   inflating: freiburg-forest/train/GT_color/b109-006_mask.png
#   inflating: freiburg-forest/train/GT_color/b595-61_mask.png
#   inflating: freiburg-forest/train/GT_color/b269-993_mask.png
#   inflating: freiburg-forest/train/GT_color/b234-196_mask.png
#   inflating: freiburg-forest/train/GT_color/b391-909_mask.png
#   inflating: freiburg-forest/train/GT_color/b730-008_mask.png
#   inflating: freiburg-forest/train/GT_color/b103-904_mask.png
#   inflating: freiburg-forest/train/GT_color/b300-011_mask.png
#   inflating: freiburg-forest/train/GT_color/b131-451_mask.png
#   inflating: freiburg-forest/train/GT_color/b283-407_mask.png
#   inflating: freiburg-forest/train/GT_color/b371-451_mask.png
#   inflating: freiburg-forest/train/GT_color/b756-81_mask.png
#   inflating: freiburg-forest/train/GT_color/b215-959_mask.png
#   inflating: freiburg-forest/train/GT_color/b53-8423_mask.png
#   inflating: freiburg-forest/train/GT_color/b5-35681_mask.png
#   inflating: freiburg-forest/train/GT_color/b85-745_mask.png
#   inflating: freiburg-forest/train/GT_color/b60-1011_mask.png
#   inflating: freiburg-forest/train/GT_color/b540-41_mask.png
#   inflating: freiburg-forest/train/GT_color/b370-76_mask.png
#   inflating: freiburg-forest/train/GT_color/b10-495_mask.png
#   inflating: freiburg-forest/train/GT_color/b75-0504_mask.png
#   inflating: freiburg-forest/train/GT_color/b285-044_mask.png
#   inflating: freiburg-forest/train/GT_color/b180-695_mask.png
#   inflating: freiburg-forest/train/GT_color/b4-20278_mask.png
#   inflating: freiburg-forest/train/GT_color/b531-009_mask.png
#   inflating: freiburg-forest/train/GT_color/b360-852_mask.png
#   inflating: freiburg-forest/train/GT_color/b85-1576_mask.png
#   inflating: freiburg-forest/train/GT_color/b76-1042_mask.png
#   inflating: freiburg-forest/train/GT_color/b112-152_mask.png
#   inflating: freiburg-forest/train/GT_color/b132-658_mask.png
#   inflating: freiburg-forest/train/GT_color/b324-805_mask.png
#   inflating: freiburg-forest/train/GT_color/b161-308_mask.png
#   inflating: freiburg-forest/train/GT_color/b32-7944_mask.png
#   inflating: freiburg-forest/train/GT_color/b102-798_mask.png
#   inflating: freiburg-forest/train/GT_color/b360-407_mask.png
#   inflating: freiburg-forest/train/GT_color/b615-962_mask.png
#   inflating: freiburg-forest/train/GT_color/b80-5434_mask.png
#   inflating: freiburg-forest/train/GT_color/b42-7599_mask.png
#   inflating: freiburg-forest/train/GT_color/b190-053_mask.png
#   inflating: freiburg-forest/train/GT_color/b805-071_mask.png
#   inflating: freiburg-forest/train/GT_color/b264-442_mask.png
#   inflating: freiburg-forest/train/GT_color/b219-143_mask.png
#   inflating: freiburg-forest/train/GT_color/b333-41_mask.png
#   inflating: freiburg-forest/train/GT_color/b98-406_mask.png
#   inflating: freiburg-forest/train/GT_color/b882-306_mask.png
#   inflating: freiburg-forest/train/GT_color/b372-406_mask.png
#   inflating: freiburg-forest/train/GT_color/b116-903_mask.png
#   inflating: freiburg-forest/train/GT_color/b93-1024_mask.png
#   inflating: freiburg-forest/train/GT_color/b47-0583_mask.png
#   inflating: freiburg-forest/train/GT_color/b85-6986_mask.png
#   inflating: freiburg-forest/train/GT_color/b502-1_mask.png
#   inflating: freiburg-forest/train/GT_color/b148-743_mask.png
#   inflating: freiburg-forest/train/GT_color/b70-8093_mask.png
#   inflating: freiburg-forest/train/GT_color/b245-904_mask.png
#   inflating: freiburg-forest/train/GT_color/b115-397_mask.png
#   inflating: freiburg-forest/train/GT_color/b836-055_mask.png
#   inflating: freiburg-forest/train/GT_color/b279-49_mask.png
#   inflating: freiburg-forest/train/GT_color/b299-305_mask.png
#   inflating: freiburg-forest/train/GT_color/b122-196_mask.png
#   inflating: freiburg-forest/train/GT_color/b396-759_mask.png
#   inflating: freiburg-forest/train/GT_color/b94-9007_mask.png
#   inflating: freiburg-forest/train/GT_color/b207-959_mask.png
#   inflating: freiburg-forest/train/GT_color/b893-107_mask.png
#   inflating: freiburg-forest/train/GT_color/b311-301_mask.png
#   inflating: freiburg-forest/train/GT_color/b115-997_mask.png
#   inflating: freiburg-forest/train/GT_color/b140-745_mask.png
#   inflating: freiburg-forest/train/GT_color/b50-3464_mask.png
#   inflating: freiburg-forest/train/GT_color/b20-6571_mask.png
#   inflating: freiburg-forest/train/GT_color/b165-789_mask.png
#   inflating: freiburg-forest/train/GT_color/b40-7064_mask.png
#   inflating: freiburg-forest/train/GT_color/b794-809_mask.png
#   inflating: freiburg-forest/train/GT_color/b315-442_mask.png
#   inflating: freiburg-forest/train/GT_color/b34-1543_mask.png
#   inflating: freiburg-forest/train/GT_color/b14-6916_mask.png
#   inflating: freiburg-forest/train/GT_color/b302-645_mask.png
#   inflating: freiburg-forest/train/GT_color/b165-558_mask.png
#   inflating: freiburg-forest/train/GT_color/b109-204_mask.png
#   inflating: freiburg-forest/train/GT_color/b8-39166_mask.png
#   inflating: freiburg-forest/train/GT_color/b137-653_mask.png
#   inflating: freiburg-forest/train/GT_color/b223-095_mask.png
#   inflating: freiburg-forest/train/GT_color/b871-504_mask.png
#   inflating: freiburg-forest/train/GT_color/b150-659_mask.png
#   inflating: freiburg-forest/train/GT_color/b170-601_mask.png
#   inflating: freiburg-forest/train/GT_color/b342-855_mask.png
#   inflating: freiburg-forest/train/GT_color/b86-045_mask.png
#   inflating: freiburg-forest/train/GT_color/b97-7585_mask.png
#   inflating: freiburg-forest/train/GT_color/b56-9018_mask.png
#   inflating: freiburg-forest/train/GT_color/b107-141_mask.png
#   inflating: freiburg-forest/train/GT_color/b118-372_mask.png
#   inflating: freiburg-forest/train/GT_color/b7-60789_mask.png
#   inflating: freiburg-forest/train/GT_color/b103-494_mask.png
#   inflating: freiburg-forest/train/GT_color/b33-4588_mask.png
#   inflating: freiburg-forest/train/GT_color/b256-688_mask.png
#   inflating: freiburg-forest/train/GT_color/b20-9997_mask.png
#   inflating: freiburg-forest/train/GT_color/b186-7_mask.png
#   inflating: freiburg-forest/train/GT_color/b156-354_mask.png
#   inflating: freiburg-forest/train/GT_color/b69-8029_mask.png
#   inflating: freiburg-forest/train/GT_color/b60-4544_mask.png
#   inflating: freiburg-forest/train/GT_color/b29-2409_mask.png
#   inflating: freiburg-forest/train/GT_color/b602-509_mask.png
#   inflating: freiburg-forest/train/GT_color/b75-8593_mask.png
#   inflating: freiburg-forest/train/GT_color/b369-154_mask.png
#   inflating: freiburg-forest/train/GT_color/b24-7604_mask.png
#   inflating: freiburg-forest/train/GT_color/b128-511_mask.png
#   inflating: freiburg-forest/train/GT_color/b68-6089_mask.png
#   inflating: freiburg-forest/train/GT_color/b106-796_mask.png
#   inflating: freiburg-forest/train/GT_color/b78-2974_mask.png
#   inflating: freiburg-forest/train/GT_color/b861-956_mask.png
#   inflating: freiburg-forest/train/GT_color/b34-1002_mask.png
#   inflating: freiburg-forest/train/GT_color/b576-103_mask.png
#   inflating: freiburg-forest/train/GT_color/b108-392_mask.png
#   inflating: freiburg-forest/train/GT_color/b196-39_mask.png
#   inflating: freiburg-forest/train/GT_color/b265-606_mask.png
#   inflating: freiburg-forest/train/GT_color/b85-3059_mask.png
#   inflating: freiburg-forest/train/GT_color/b147-797_mask.png
#   inflating: freiburg-forest/train/GT_color/b852-657_mask.png
#   inflating: freiburg-forest/train/GT_color/b295-671_mask.png
#   inflating: freiburg-forest/train/GT_color/b137-492_Clipped.png
#   inflating: freiburg-forest/train/GT_color/b234-66_mask.png
#   inflating: freiburg-forest/train/GT_color/b116-1_mask.png
#   inflating: freiburg-forest/train/GT_color/b20-6984_mask.png
#   inflating: freiburg-forest/train/GT_color/b165-003_mask.png
#   inflating: freiburg-forest/train/GT_color/b248-492_mask.png
#   inflating: freiburg-forest/train/GT_color/b20-8017_mask.png
#   inflating: freiburg-forest/train/GT_color/b51-4968_mask.png
#   inflating: freiburg-forest/train/GT_color/b206-696_mask.png
#   inflating: freiburg-forest/train/GT_color/b201-803_mask.png
#   inflating: freiburg-forest/train/GT_color/b551-215_mask.png
#   inflating: freiburg-forest/train/GT_color/b152-009_mask.png
#   inflating: freiburg-forest/train/GT_color/b511-704_mask.png
#   inflating: freiburg-forest/train/GT_color/b293-413_mask.png
#   inflating: freiburg-forest/train/GT_color/b77-9598_mask.png
#   inflating: freiburg-forest/train/GT_color/b350-605_mask.png
#   inflating: freiburg-forest/train/GT_color/b336-894_mask.png
#   inflating: freiburg-forest/train/GT_color/b128-847_mask.png
#   inflating: freiburg-forest/train/GT_color/b154-945_mask.png
#   inflating: freiburg-forest/train/GT_color/b875-908_mask.png
#   inflating: freiburg-forest/train/GT_color/b623-762_mask.png
#   inflating: freiburg-forest/train/GT_color/b562-313_mask.png
#   inflating: freiburg-forest/train/GT_color/b741-765_mask.png
#   inflating: freiburg-forest/train/GT_color/b154-308_mask.png
#   inflating: freiburg-forest/train/GT_color/b119-3_mask.png
#   inflating: freiburg-forest/train/GT_color/b2-05528_mask.png
#   inflating: freiburg-forest/train/GT_color/b241-386_mask.png
#   inflating: freiburg-forest/train/GT_color/b175-943_mask.png
#   inflating: freiburg-forest/train/GT_color/b145-013_mask.png
#   inflating: freiburg-forest/train/GT_color/b125-992_mask.png
#   inflating: freiburg-forest/train/GT_color/b31-9452_mask.png
#   inflating: freiburg-forest/train/GT_color/b95-0932_mask.png
#   inflating: freiburg-forest/train/GT_color/b565-36_mask.png
#   inflating: freiburg-forest/train/GT_color/b56-5961_mask.png
#   inflating: freiburg-forest/train/GT_color/b766-607_mask.png
#   inflating: freiburg-forest/train/GT_color/b255-259_mask.png
#   inflating: freiburg-forest/train/GT_color/b67-8434_mask.png
#   inflating: freiburg-forest/train/GT_color/b210-107_mask.png
#   inflating: freiburg-forest/train/GT_color/b63-3399_mask.png
#   inflating: freiburg-forest/train/GT_color/b61-0124_mask.png
#   inflating: freiburg-forest/train/GT_color/b90-3976_mask.png
#   inflating: freiburg-forest/train/GT_color/b69-845_mask.png
#   inflating: freiburg-forest/train/GT_color/b96-8946_mask.png
#   inflating: freiburg-forest/train/GT_color/b1-99445_mask.png
#   inflating: freiburg-forest/train/GT_color/b130-441_mask.png
#   inflating: freiburg-forest/train/GT_color/b347-196_mask.png
#   inflating: freiburg-forest/train/GT_color/b93-8539_mask.png
#   inflating: freiburg-forest/train/GT_color/b33-7457_mask.png
#   inflating: freiburg-forest/train/GT_color/b114-218_mask.png
#   inflating: freiburg-forest/train/GT_color/b73-2942_mask.png
#   inflating: freiburg-forest/train/GT_color/b86-1078_mask.png
#   inflating: freiburg-forest/train/GT_color/b60-607_mask.png
#   inflating: freiburg-forest/train/GT_color/b195-161_mask.png
#   inflating: freiburg-forest/train/GT_color/b323-5_mask.png
#   inflating: freiburg-forest/train/GT_color/b55-3998_mask.png
#   inflating: freiburg-forest/train/GT_color/b225-405_mask.png
#   inflating: freiburg-forest/train/GT_color/b50-4465_mask.png
#   inflating: freiburg-forest/train/GT_color/b130-487_mask.png
#   inflating: freiburg-forest/train/GT_color/b227-247_mask.png
#   inflating: freiburg-forest/train/GT_color/b140-809_mask.png
#   inflating: freiburg-forest/train/GT_color/b50-2417_mask.png
#   inflating: freiburg-forest/train/GT_color/b80-9607_mask.png
#   inflating: freiburg-forest/train/GT_color/b5-09922_mask.png
#   inflating: freiburg-forest/train/GT_color/b274-209_mask.png
#   inflating: freiburg-forest/train/GT_color/b50-2055_mask.png
#   inflating: freiburg-forest/train/GT_color/b113-392_mask.png
#   inflating: freiburg-forest/train/GT_color/b65-6474_mask.png
#   inflating: freiburg-forest/train/GT_color/b40-2921_mask.png
#   inflating: freiburg-forest/train/GT_color/b234-046_mask.png
#   inflating: freiburg-forest/train/GT_color/b240-76_mask.png
#   inflating: freiburg-forest/train/GT_color/b117-844_mask.png
#   inflating: freiburg-forest/train/GT_color/b216-59_mask.png
#   inflating: freiburg-forest/train/GT_color/b243-943_mask.png
#   inflating: freiburg-forest/train/GT_color/b146-945_mask.png
#   inflating: freiburg-forest/train/GT_color/b378-299_mask.png
#   inflating: freiburg-forest/train/GT_color/b24-5502_mask.png
#   inflating: freiburg-forest/train/GT_color/b357-564_mask.png
#   inflating: freiburg-forest/train/GT_color/b844-317_mask.png
#   inflating: freiburg-forest/train/GT_color/b187-799_mask.png
#   inflating: freiburg-forest/train/GT_color/b34-743_mask.png
#   inflating: freiburg-forest/train/GT_color/b121-193_mask.png
#   inflating: freiburg-forest/train/GT_color/b579-255_mask.png
#   inflating: freiburg-forest/train/GT_color/b569-315_mask.png
#   inflating: freiburg-forest/train/GT_color/b73-1482_mask.png
#   inflating: freiburg-forest/train/GT_color/b88-8491_mask.png
#   inflating: freiburg-forest/train/GT_color/b242-953_mask.png
#   inflating: freiburg-forest/train/GT_color/b342-204_mask.png
#   inflating: freiburg-forest/train/GT_color/b134-087_Clipped.png
#   inflating: freiburg-forest/train/GT_color/b97-1436_mask.png
#   inflating: freiburg-forest/train/GT_color/b94-8062_mask.png
#   inflating: freiburg-forest/train/GT_color/b90-3124_mask.png
#   inflating: freiburg-forest/train/GT_color/b76-2943_mask.png
#   inflating: freiburg-forest/train/GT_color/b314-513_mask.png
#   inflating: freiburg-forest/train/GT_color/b289-404_mask.png
#   inflating: freiburg-forest/train/GT_color/b364-909_mask.png
#   inflating: freiburg-forest/train/GT_color/b204-354_mask.png
#   inflating: freiburg-forest/train/GT_color/b41-3444_mask.png
#   inflating: freiburg-forest/train/GT_color/b160-646_mask.png
#   inflating: freiburg-forest/train/GT_color/b205-86_mask.png
#   inflating: freiburg-forest/train/GT_color/b350-449_mask.png
#   inflating: freiburg-forest/train/GT_color/b211-549_mask.png
#   inflating: freiburg-forest/train/GT_color/b40-945_mask.png
#   inflating: freiburg-forest/train/GT_color/b85-7951_mask.png
#   inflating: freiburg-forest/train/GT_color/b81-2487_mask.png
#   inflating: freiburg-forest/train/GT_color/b54-0624_mask.png
#   inflating: freiburg-forest/train/GT_color/b175-664_mask.png
#   inflating: freiburg-forest/train/GT_color/b355-702_mask.png
#   inflating: freiburg-forest/train/GT_color/b138-651_mask.png
#   inflating: freiburg-forest/train/GT_color/b14-9983_mask.png
#   inflating: freiburg-forest/train/GT_color/b341-655_mask.png
#   inflating: freiburg-forest/train/GT_color/b751-559_mask.png
#    creating: freiburg-forest/train/rgb/
#   inflating: freiburg-forest/train/rgb/b85-745_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b138-651_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b146-945_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b160-646_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b10-495_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b241-386_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b457-708_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b24-5502_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b255-259_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b300-011_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b75-8593_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b80-5434_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b502-1_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b20-8017_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b794-809_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b350-449_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b116-1_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b264-442_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b242-953_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b152-009_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b76-1042_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b190-053_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b137-492_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b293-413_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b148-743_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b227-247_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b113-392_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b50-2055_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b33-7457_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b186-7_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b156-354_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b265-606_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b34-1002_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b40-945_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b116-903_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b29-2409_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b175-943_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b41-3444_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b154-945_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b540-41_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b576-103_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b130-441_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b861-956_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b756-81_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b852-657_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b623-762_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b137-653_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b201-803_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b165-003_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b112-152_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b107-141_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b75-0504_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b551-215_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b195-161_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b579-255_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b302-645_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b60-607_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b34-743_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b68-6089_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b360-407_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b69-8029_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b565-36_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b210-107_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b128-511_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b805-071_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b86-045_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b315-442_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b882-306_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b1-99445_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b370-76_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b342-204_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b94-8062_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b295-671_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b180-695_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b323-5_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b117-844_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b595-61_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b118-372_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b154-308_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b511-704_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b274-209_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b364-909_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b871-504_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b109-204_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b170-601_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b215-959_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b243-943_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b108-392_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b5-35681_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b103-494_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b311-301_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b7-60789_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b150-659_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b73-1482_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b283-407_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b85-1576_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b94-9007_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b95-0932_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b98-406_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b131-451_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b219-143_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b378-299_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b134-087_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b204-354_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b51-4968_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b248-492_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b161-308_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b562-313_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b50-2417_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b109-006_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b8-39166_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b121-193_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b372-406_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b61-0124_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b85-6986_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b69-845_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b90-3124_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b56-5961_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b187-799_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b4-20278_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b50-3464_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b140-809_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b60-4544_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b165-558_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b14-9983_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b196-39_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b42-7599_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b24-7604_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b86-1078_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b290-499_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b299-305_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b391-909_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b371-451_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b216-59_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b78-2974_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b102-798_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b122-196_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b85-3059_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b147-797_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b34-1543_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b836-055_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b360-852_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b81-2487_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b115-397_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b125-992_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b165-789_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b2-05528_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b285-044_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b225-405_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b130-487_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b342-855_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b60-1011_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b741-765_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b240-76_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b175-664_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b93-8539_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b279-49_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b355-702_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b50-4465_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b40-2921_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b76-2943_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b207-959_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b115-997_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b96-8946_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b97-1436_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b90-3976_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b54-0624_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b70-8093_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b20-9997_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b93-1024_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b615-962_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b531-009_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b766-607_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b206-696_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b40-7064_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b269-993_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b289-404_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b132-658_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b245-904_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b114-218_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b55-3998_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b53-8423_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b602-509_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b369-154_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b88-8491_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b347-196_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b103-904_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b350-605_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b333-41_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b106-796_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b140-745_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b324-805_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b145-013_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b205-86_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b341-655_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b63-3399_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b65-6474_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b119-3_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b223-095_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b569-315_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b20-6571_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b844-317_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b751-559_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b336-894_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b396-759_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b234-196_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b234-66_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b730-008_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b32-7944_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b234-046_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b893-107_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b73-2942_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b875-908_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b31-9452_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b77-9598_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b314-513_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b56-9018_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b80-9607_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b67-8434_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b20-6984_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b47-0583_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b128-847_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b97-7585_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b14-6916_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b211-549_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b85-7951_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b357-564_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b5-09922_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b256-688_Clipped.jpg
#   inflating: freiburg-forest/train/rgb/b33-4588_Clipped.jpg
#    creating: freiburg-forest/test/
#   inflating: freiburg-forest/test/LICENSE.txt
#    creating: freiburg-forest/test/GT_color/
#   inflating: freiburg-forest/test/GT_color/b355-156_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b102-153_mask.png
#   inflating: freiburg-forest/test/GT_color/b307-706_mask.png
#   inflating: freiburg-forest/test/GT_color/b229-246_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b771-056_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b90-5572_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b21-5419_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b260-404_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b347-195_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b170-562_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b786-807_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b12-6641_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b41-302_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b39-0038_mask.png
#   inflating: freiburg-forest/test/GT_color/b92-655_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b188-608_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b378-61_mask.png
#   inflating: freiburg-forest/test/GT_color/b395-296_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b412-244_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b113-994_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b122-466_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b505-454_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b91-9453_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b200-26_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b25-0024_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b80-3938_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b14-5948_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b103-051_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b310-294_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b52-3061_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b115-901_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b80-6958_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b19-8972_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b197-61_mask.png
#   inflating: freiburg-forest/test/GT_color/b27-6951_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b36-8607_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b316-605_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b45-1443_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b585-708_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b139-146_mask.png
#   inflating: freiburg-forest/test/GT_color/b200-391_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b246-244_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b289-945_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b145-541_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b527-508_mask.png
#   inflating: freiburg-forest/test/GT_color/b365-302_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b78-9987_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b335-148_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b57-8406_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b190-964_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b337-706_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b326-451_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b103-349_mask.png
#   inflating: freiburg-forest/test/GT_color/b362-81_mask.png
#   inflating: freiburg-forest/test/GT_color/b115-207_mask.png
#   inflating: freiburg-forest/test/GT_color/b311-413_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b235-398_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b265-644_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b260-192_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b160-301_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b243-252_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b15-6604_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b223-904_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b181-953_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b1-09517_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b98-2008_mask.png
#   inflating: freiburg-forest/test/GT_color/b80-9467_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b865-162_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b336-053_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b330-796_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b151-546_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b221-358_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b45-0046_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b188-654_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b747-009_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b215-11_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b25-896_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b278-203_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b201-852_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b145-947_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b123-752_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b110-598_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b96-4043_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b275-348_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b46-4456_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b2-459_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b309-597_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b144-307_mask.png
#   inflating: freiburg-forest/test/GT_color/b100-943_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b168-197_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b573-607_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b304-36_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b80-1093_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b37-0412_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b351-165_mask.png
#   inflating: freiburg-forest/test/GT_color/b85-0043_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b76-2463_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b118-047_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b160-994_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b275-311_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b230-561_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b110-303_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b72-8498_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b220-902_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b335-347_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b344-048_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b91-0929_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b60-696_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b373-105_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b83-8006_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b46-4068_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b191-493_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b32-8988_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b212-044_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b314-504_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b56-5476_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b817-76_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b288-699_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b250-96_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b606-757_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b123-194_mask.png
#   inflating: freiburg-forest/test/GT_color/b46-046_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b69-9448_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b221-999_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b77-896_mask.png
#   inflating: freiburg-forest/test/GT_color/b253-299_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b72-6612_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b257-749_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b251-101_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b65-2041_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b140-547_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b475-057_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b11-8452_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b69-0438_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b555-805_Clipped.png
#   inflating: freiburg-forest/test/GT_color/b7-29602_Clipped.png
#   inflating: freiburg-forest/test/README.txt
#    creating: freiburg-forest/test/rgb/
#   inflating: freiburg-forest/test/rgb/b72-6612_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b505-454_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b12-6641_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b1-09517_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b113-994_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b21-5419_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b223-904_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b85-0043_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b188-654_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b310-294_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b251-101_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b110-598_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b316-605_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b309-597_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b83-8006_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b475-057_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b191-493_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b330-796_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b865-162_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b311-413_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b80-1093_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b250-96_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b91-9453_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b76-2463_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b65-2041_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b585-708_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b355-156_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b2-459_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b69-0438_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b45-0046_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b395-296_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b118-047_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b15-6604_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b606-757_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b212-044_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b243-252_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b69-9448_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b747-009_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b80-3938_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b188-608_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b170-562_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b19-8972_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b115-901_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b362-81_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b90-5572_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b46-4068_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b304-36_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b275-348_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b229-246_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b307-706_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b253-299_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b351-165_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b39-0038_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b289-945_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b80-6958_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b200-26_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b139-146_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b144-307_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b197-61_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b41-302_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b123-194_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b160-301_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b378-61_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b14-5948_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b168-197_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b344-048_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b56-5476_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b80-9467_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b25-896_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b786-807_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b246-244_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b555-805_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b336-053_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b288-699_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b265-644_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b260-404_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b221-358_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b25-0024_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b32-8988_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b52-3061_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b92-655_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b573-607_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b278-203_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b151-546_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b123-752_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b771-056_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b230-561_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b60-696_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b337-706_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b257-749_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b37-0412_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b347-195_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b46-046_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b45-1443_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b160-994_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b235-398_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b412-244_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b7-29602_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b98-2008_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b122-466_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b181-953_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b140-547_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b335-148_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b46-4456_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b190-964_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b11-8452_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b221-999_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b103-051_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b275-311_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b314-504_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b96-4043_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b102-153_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b100-943_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b260-192_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b527-508_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b110-303_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b373-105_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b335-347_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b215-11_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b115-207_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b72-8498_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b201-852_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b145-541_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b36-8607_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b145-947_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b200-391_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b220-902_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b326-451_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b78-9987_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b103-349_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b57-8406_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b365-302_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b27-6951_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b817-76_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b91-0929_Clipped.jpg
#   inflating: freiburg-forest/test/rgb/b77-896_Clipped.jpg

# %%
# useful imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

import torchvision
import torch.utils.data
from torch.utils.data import DataLoader
from torchvision.utils import save_image
import torchvision.transforms as transforms

import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Preprocessing

# %%
import os
import glob
from PIL import Image, ImageOps
import torchvision.transforms as transforms
from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, map_path, img_path, transform=None):
        super(CustomDataset, self).__init__()

        self.map_path = glob.glob(os.path.join(map_path, '*_mask.png'))
        
        self.img_path = [os.path.join(img_path, os.path.basename(fname)[:-9]+'_Clipped.jpg') for fname in self.map_path]

        transform_list = [transforms.ToTensor()]
        self.transform = transforms.Compose(transform_list)

    def __getitem__(self, index):
        label_map = Image.open(self.map_path[index])
        label_map = ImageOps.fit(label_map, (512, 256), Image.NEAREST)
        label_map = label_map.convert('RGB')
        label_map = self.transform(label_map)

        img = Image.open(self.img_path[index])
        img = ImageOps.fit(img, (512, 256), Image.NEAREST)
        img = img.convert('RGB')
        img = self.transform(img)
        
        return label_map, img
    
    def __len__(self):
        return len(self.img_path)

# %%
map_dir = 'freiburg-forest/train/GT_color/'
img_dir = 'freiburg-forest/train/rgb/'
batch_size = 1
dataset = CustomDataset(map_dir, img_dir)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=1)

map_dir_test = 'freiburg-forest/test/GT_color/'
img_dir_test = 'freiburg-forest/test/rgb/'
batch_size = 1
dataset_test = CustomDataset(map_dir_test, img_dir_test)
dataloader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=True, num_workers=1)

# %% [markdown]
# ## Define Networks

# %%
# Residual Block
class ResBlock(nn.Module):
    def __init__(self, dim, padding_type, norm_layer=nn.BatchNorm2d, activation=nn.ReLU(True)):
        super(ResBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, activation)

    def build_conv_block(self, dim, padding_type, norm_layer, activation):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block.append(nn.ReflectionPad2d(1))
        elif padding_type == 'replicate':
            conv_block.append(nn.ReplicationPad2d(1))
        elif padding_type == 'zero':
            p = 1
        else:
            print("padding type not implemented.")
        
        conv_block.extend([nn.Conv2d(dim, dim, kernel_size=3, padding=p),
                       norm_layer(dim), activation])
        
        p = 0
        if padding_type == 'reflect':
            conv_block.append(nn.ReflectionPad2d(1))
        elif padding_type == 'replicate':
            conv_block.append(nn.ReplicationPad2d(1))
        elif padding_type == 'zero':
            p = 1
        else:
            print("padding type not implemented.")
        conv_block.extend([nn.Conv2d(dim, dim, kernel_size=3, padding=p),
                       norm_layer(dim), activation])
        
        return nn.Sequential(*conv_block)
    
    def forward(self, x):
        return x + self.conv_block(x)

# %%
# G1, global generator
class GlobalGenerator(nn.Module):
    def __init__(self, input_nc, output_nc, ngf=64, 
                 n_downsampling=3, n_blocks=6, norm_layer=nn.BatchNorm2d, padding_type='reflect'):
        
        super(GlobalGenerator, self).__init__()

        model = [nn.ReflectionPad2d(3), nn.Conv2d(input_nc, ngf, kernel_size=7, padding=0),
                 norm_layer(ngf), nn.ReLU(True)]
        
        # downsample
        for i in range(n_downsampling):
            model.extend([nn.Conv2d(ngf*(2**i), ngf*(2**(i+1)), kernel_size=3, stride=2, padding=1),
                      norm_layer(ngf*(2**(i+1))), nn.ReLU(True)])
            
        # resnet blocks
        mult = 2**n_downsampling
        for i in range(n_blocks):
            model.append(ResBlock(ngf*mult, padding_type=padding_type, 
                               activation=nn.ReLU(True), norm_layer=norm_layer))
            
        # upsample
        for i in range(n_downsampling):
            mult = 2**(n_downsampling - i)
            model.extend([nn.ConvTranspose2d(ngf*mult, int(ngf*mult/2), kernel_size=3, stride=2, padding=1, output_padding=1), 
                          norm_layer(int(ngf*mult/2)), nn.ReLU(True)])
        
        model.append(nn.ReflectionPad2d(3))
        model.append(nn.Conv2d(ngf, output_nc, kernel_size=7, padding=0))
        model.append(nn.Tanh())
        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %%
# local enhancer
class LocalEnhancer(nn.Module):
    def __init__(self, input_nc, output_nc, model_global, ngf=32, n_downsample_global=3, n_blocks_gobal=6,
                n_local_enhancers=1, n_blocks_local=3, norm_layer=nn.BatchNorm2d, padding_type='reflect'):
        super(LocalEnhancer, self).__init__()
        self.n_local_enhancers = n_local_enhancers
        self.model_global = model_global.model

        # global generator model
        mult = 2**n_local_enhancers
        ngf_global = ngf * mult
        # model_global = GlobalGenerator(input_nc, output_nc, ngf_global, n_downsample_global, n_blocks_gobal, norm_layer).model
        model_global = [self.model_global[i] for i in range(len(self.model_global)-3)] # get rid of final conv layers
        self.model = nn.Sequential(*model_global)

        self.downsample = nn.AvgPool2d(3, stride=2, padding=[1, 1], count_include_pad=False)
        
        # local enhancer layers
        for n in range(1, n_local_enhancers+1):
            # downsample
            mult = 2**(n_local_enhancers-n)
            ngf_global = ngf * mult
            model_downsample = []
            model_downsample_block1 = [nn.ReflectionPad2d(3), nn.Conv2d(input_nc, ngf_global, kernel_size=7, padding=0),
                                norm_layer(ngf_global), nn.ReLU(True)]
            model_downsample_block2 = [nn.Conv2d(ngf_global, ngf_global*2, kernel_size=3, stride=2, padding=1),
                                norm_layer(ngf_global*2), nn.ReLU(True)]
            model_downsample.extend(model_downsample_block1)
            model_downsample.extend(model_downsample_block2)
            
            # residul blocks
            model_upsample = []
            for i in range(n_blocks_local):
                model_upsample.append(ResBlock(ngf_global * 2, padding_type=padding_type, norm_layer=norm_layer))
            
            # upsample
            model_upsample.extend([nn.ConvTranspose2d(ngf_global * 2, ngf_global, 
                                                kernel_size=3, stride=2, padding=1, output_padding=1),
                                norm_layer(ngf_global), nn.ReLU(True)])
            
            # final convolution
            if n == n_local_enhancers:
                model_upsample.extend([nn.ReflectionPad2d(3), nn.Conv2d(ngf, output_nc, kernel_size=7, padding=0), nn.Tanh()])
            
            self.le_downsample = nn.Sequential(*model_downsample)
            self.le_upsample =  nn.Sequential(*model_upsample)

    
    def forward(self, x):
        # create input pyramid
        input_downsampled = [x]
        for i in range(self.n_local_enhancers):
            input_downsampled.append(self.downsample(input_downsampled[-1]))
        
        # output at coarest level
        output_prev = self.model(input_downsampled[-1])
        # build up one layer at a time
        model_downsample = self.le_downsample
        model_upsample = self.le_upsample
        for n_local_enhancers in range(1, self.n_local_enhancers+1):
            # downsample            
            input_i = input_downsampled[self.n_local_enhancers-n_local_enhancers]
            # upsample
            output_prev = model_upsample(model_downsample(input_i) + output_prev)
        return output_prev

# %%
class NLayerDiscriminator(nn.Module):
    def __init__(self, input_nc, ndf=64, n_layers=3, norm_layer=nn.BatchNorm2d):
        super(NLayerDiscriminator, self).__init__()
        self.n_layers = n_layers

        model = [nn.Conv2d(input_nc, ndf, kernel_size=4, stride=2, padding=2), nn.LeakyReLU(0.2, True)]

        nf = ndf
        for n in range(1, n_layers):
            nf_prev = nf
            nf = min(nf*2, 512)
            model.extend([
                nn.Conv2d(nf_prev, nf, kernel_size=4, stride=2, padding=2),
                norm_layer(nf), 
                nn.LeakyReLU(0.2, True)
            ])
        
        nf_prev = nf
        nf = min(nf*2, 512)
        model.extend([
            nn.Conv2d(nf_prev, nf, kernel_size=4, stride=1, padding=2),
            norm_layer(nf),
            nn.LeakyReLU(0.2, True)
        ])

        model.append(nn.Conv2d(nf, 1, kernel_size=4, stride=1, padding=2))

        self.model = nn.Sequential(*model)
    
    def forward(self, x):
        return self.model(x)

# %%
# multiscale discriminator
class MultiscaleDiscriminator(nn.Module):
    def __init__(self, input_nc, ndf=64, n_layers=3, norm_layer=nn.BatchNorm2d, num_D=3):
        super(MultiscaleDiscriminator, self).__init__()
        self.num_D = num_D
        self.n_layers = n_layers
        self.downsample = nn.AvgPool2d(3, stride=2, padding=[1, 1], count_include_pad=False)
        
        # build n discriminators
        for i in range(num_D):
            netD = NLayerDiscriminator(input_nc, ndf, n_layers, norm_layer)
            setattr(self, 'layer'+str(i), netD.model)
    
    def singleD_forward(self, model, x):
        return model(x)
    
    def forward(self, x):
        num_D = self.num_D
        result = []
        input_downsampled = x
        for i in range(num_D):
            model = getattr(self, 'layer'+str(num_D-i-1))
            result.append(self.singleD_forward(model, input_downsampled))
            if i != num_D-1:
                input_downsampled = self.downsample(input_downsampled)
        return result

# %%
# using pretrained vgg19 model from pytorch
from torchvision import models
class Vgg19(torch.nn.Module):
    def __init__(self, requires_grad=False):
        super(Vgg19, self).__init__()
        vgg_pretrained_features = models.vgg19(pretrained=True).features

        slice1 = []
        slice2 = []
        slice3 = []
        slice4 = []
        slice5 = []
        for x in range(2):
            slice1.append(vgg_pretrained_features[x])
        for x in range(2, 7):
            slice2.append(vgg_pretrained_features[x])
        for x in range(7, 12):
            slice3.append(vgg_pretrained_features[x])
        for x in range(12, 21):
            slice4.append(vgg_pretrained_features[x])
        for x in range(21, 30):
            slice5.append(vgg_pretrained_features[x])
        if not requires_grad:
            for param in self.parameters():
                param.requires_grad = False

        self.slice1 = torch.nn.Sequential(*slice1)
        self.slice2 = torch.nn.Sequential(*slice2)
        self.slice3 = torch.nn.Sequential(*slice3)
        self.slice4 = torch.nn.Sequential(*slice4)
        self.slice5 = torch.nn.Sequential(*slice5)

    def forward(self, x):
        relu1 = self.slice1(x)
        relu2 = self.slice2(relu1)        
        relu3 = self.slice3(relu2)        
        relu4 = self.slice4(relu3)        
        relu5 = self.slice5(relu4)                
        return [relu1, relu2, relu3, relu4, relu5]

class VGGLoss(nn.Module):
    def __init__(self):
        super(VGGLoss, self).__init__()        
        self.vgg19 = Vgg19().cuda()
        self.crit = nn.L1Loss()       

    def forward(self, x, y):              
        x_vgg, y_vgg = self.vgg19(x), self.vgg19(y)
        weights = [1.0/32, 1.0/16, 1.0/8, 1.0/4, 1.0]
        loss = 0
        for i in range(len(x_vgg)):
            loss_each_slice = weights[i] * self.crit(x_vgg[i], y_vgg[i].detach())
            loss += loss_each_slice        
        return loss

# %%
class pix2pixHD(nn.Module):
    def __init__(self, num_D, generator, discriminator, device):
        super(pix2pixHD, self).__init__()
        # vgg loss
        self.vgg_loss = VGGLoss()
        self.criterionGAN = nn.MSELoss()
        self.device = device
        # pass parameters
        self.num_D = num_D
        self.generator = generator
        self.discriminator = discriminator
        self.feat_loss = nn.L1Loss()


    def GANloss(self, input_img, is_real):
        if is_real:
            label = 1
        else:
            label = 0
        
        # no instance
        target = torch.Tensor(input_img[-1].size()).fill_(label).to(input_img[-1].device)
        return self.criterionGAN(input_img[-1], target)


    def forward(self, label_map, real_image):
        self.generator = self.generator.to(self.device)
        self.generator.train()
        self.discriminator = self.discriminator.to(self.device)
        
        fake_image = self.generator(label_map.to(self.device))

        # fake loss
        pred_fake = self.discriminator(torch.cat((label_map, fake_image.detach()), dim=1))
        loss_D_fake = self.GANloss(pred_fake, is_real=False)

        # real loss
        pred_real = self.discriminator(torch.cat((label_map, real_image.detach()), dim=1))
        loss_D_real = self.GANloss(pred_real, is_real=True)

        # GAN loss: fake passability loss
        pred_GAN = self.discriminator(torch.cat((label_map, fake_image), dim=1))
        loss_GAN = self.GANloss(pred_GAN, is_real=True)

        # feature matching loss
        loss_FM = 0
        D_weights = 1.0/self.num_D
        for i in range(self.num_D):
            for j in range(len(pred_fake[i])-1):
                loss_FM += D_weights * self.feat_loss(pred_fake[i][j], pred_real[i][j].detach()) * 10.0
        
        # vgg loss
        loss_VGG = self.vgg_loss(fake_image, real_image) * 10.0

        return loss_D_fake, loss_D_real, loss_GAN, loss_FM, loss_VGG, fake_image

# %% [markdown]
# ## Training & Testing

# %%
# model paths
global_model = "/content/drive/My Drive/3rd-year-project/forest-model/generator_model_global"
local_model = "/content/drive/My Drive/3rd-year-project/forest-model/generator_model_local"
discriminator_model_path = "/content/drive/My Drive/3rd-year-project/forest-model/discriminator_model"

# %%
import matplotlib.pyplot as plt
def train():
    loss_gen_list = []
    loss_dis_list = []
    train_start_time = time.time()
    trace_start_time = time.time()
    for epoch in range(1, num_epoch+1):
        epoch_start_time = time.time()
        for i, data in enumerate(dataloader):
            # forward pass
            label_map, real_image = data
            label_map = label_map.to(device)
            real_image = real_image.to(device)
            
            loss_D_fake, loss_D_real, loss_GAN, loss_FM, loss_VGG, fake_image = model(label_map, real_image)
            
            # calculate final losses
            loss_G = loss_GAN + loss_FM + loss_VGG
            loss_D = (loss_D_fake + loss_D_real) * 0.5

            # update generator weights
            optimizer_G.zero_grad()
            loss_G.backward()
            optimizer_G.step()

            # update discriminator weights
            optimizer_D.zero_grad()
            loss_D.backward()
            optimizer_D.step()
        
        # end of epoch
        epoch_end_time = time.time()

        # display results
        if epoch % trace_freq == 1 or epoch == num_epoch:
            trace_end_time = time.time()

            # print out errors
            print('End of epoch: %d / %d Time Taken: %d sec' %
            (epoch, num_epoch, trace_end_time - trace_start_time))
            print("Generator loss: " + str(loss_G.item()))
            print("Discriminator loss: " + str(loss_D.item()))

            img = torchvision.utils.make_grid([label_map[0].cpu(), fake_image[0].cpu(), real_image[0].cpu()],
                                                nrow=3)
            plt.figure(figsize=(18, 18))
            plt.imshow(img.permute(1, 2, 0).detach().numpy())
            plt.show()

            print("Test result:")
            for j, data_test in enumerate(dataloader_test):
                input_image, real_image = data_test
                input_image.to(device)
                real_image.to(device)
                
                fake_image = generator(input_image.to(device))
                img = torchvision.utils.make_grid([input_image[0].cpu(), fake_image[0].cpu(), real_image[0].cpu()],
                                                        nrow=3)
                plt.figure(figsize=(18, 18))
                plt.imshow(img.permute(1, 2, 0).detach().numpy())
                plt.show()

                break
            
            trace_start_time = time.time()
            
            
        # save checkpoints for iteration
        # save checkpoints for epochs
        torch.save(generator.cpu().state_dict(), generator_model_path)
        torch.save(discriminator.cpu().state_dict(), discriminator_model_path)

        # save loss into lists
        loss_gen_list.append(loss_G.item())
        loss_dis_list.append(loss_D.item())
    train_end_time = time.time()
    print("Total training time: " + str(train_end_time - train_start_time))
    return loss_gen_list, loss_dis_list

# %%
# initialization G1
learning_rate_G = 2e-5
learning_rate_D = 1e-5
train_global = True
continue_train = False

if train_global == False:
    generator_global = GlobalGenerator(3, 3)
    generator_global.load_state_dict(torch.load(global_model))
    generator = LocalEnhancer(3, 3, generator_global).to(device)
    generator_model_path = local_model
else:
    generator = GlobalGenerator(3, 3).to(device)
    generator_model_path = global_model

discriminator = MultiscaleDiscriminator(input_nc=6).to(device)

if continue_train:
    generator.load_state_dict(torch.load(generator_model_path))
    discriminator.load_state_dict(torch.load(discriminator_model_path))
elif train_global == False:
    discriminator.load_state_dict(torch.load(discriminator_model_path))

generator.train()
generator.to(device)
discriminator.train()
model = pix2pixHD(num_D=3, generator=generator, discriminator=discriminator, device=device).to(device)

optimizer_G = optim.Adam(generator.parameters(), lr=learning_rate_G)
optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate_D)

# %%
# global generator
# epoch trained: 200
num_epoch = 200
trace_freq = 20
loss_gen, loss_dis = train()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(1, len(loss_gen)+1)
loss_gen = np.array(loss_gen)
loss_dis = np.array(loss_dis)
fig, axs = plt.subplots()
axs.plot(t, loss_gen, label="generator loss")
axs.plot(t, loss_dis, label="discriminator loss")
axs.set_xlim(0, 200)
axs.set_xlabel('epochs')
axs.set_ylabel('loss for generator and discriminator')
axs.grid(True)

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

fig.tight_layout()
plt.show()

# %%
class CustomDataset(Dataset):
    def __init__(self, map_path, img_path, transform=None):
        super(CustomDataset, self).__init__()

        self.map_path = glob.glob(os.path.join(map_path, '*_mask.png'))
        
        self.img_path = [os.path.join(img_path, os.path.basename(fname)[:-9]+'_Clipped.jpg') for fname in self.map_path]

        transform_list = [transforms.ToTensor()]
        self.transform = transforms.Compose(transform_list)

    def __getitem__(self, index):
        label_map = Image.open(self.map_path[index])
        label_map = ImageOps.fit(label_map, (1024, 512), Image.NEAREST)
        label_map = label_map.convert('RGB')
        label_map = self.transform(label_map)

        img = Image.open(self.img_path[index])
        img = ImageOps.fit(img, (1024, 512), Image.NEAREST)
        img = img.convert('RGB')
        img = self.transform(img)
        
        return label_map, img
    
    def __len__(self):
        return len(self.img_path)


map_dir = 'freiburg-forest/train/GT_color/'
img_dir = 'freiburg-forest/train/rgb/'
batch_size = 1
dataset = CustomDataset(map_dir, img_dir)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=1)

map_dir_test = 'freiburg-forest/test/GT_color/'
img_dir_test = 'freiburg-forest/test/rgb/'
batch_size = 1
dataset_test = CustomDataset(map_dir_test, img_dir_test)
dataloader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=True, num_workers=1)

# %%
# initialization G2
learning_rate_G = 2e-5
learning_rate_D = 1e-5
train_global = False
continue_train = False

if train_global == False:
    generator_global = GlobalGenerator(3, 3)
    generator_global.load_state_dict(torch.load(global_model))
    generator = LocalEnhancer(3, 3, generator_global).to(device)
    generator_model_path = local_model
else:
    generator = GlobalGenerator(3, 3).to(device)
    generator_model_path = global_model

discriminator = MultiscaleDiscriminator(input_nc=6).to(device)

if continue_train:
    generator.load_state_dict(torch.load(generator_model_path))
    discriminator.load_state_dict(torch.load(discriminator_model_path))
elif train_global == False:
    discriminator.load_state_dict(torch.load(discriminator_model_path))

generator.train()
generator.to(device)
discriminator.train()
model = pix2pixHD(num_D=3, generator=generator, discriminator=discriminator, device=device).to(device)

optimizer_G = optim.Adam(generator.parameters(), lr=learning_rate_G)
optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate_D)

# %%
# local enhancer
# epoch trained: 100
num_epoch = 100
trace_freq = 10
loss_gen, loss_dis = train()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# save loss data into files
loss_gen_file = open('/content/drive/My Drive/3rd-year-project/forest-model/loss_gen.txt', 'w')
for loss in loss_gen:
	loss_gen_file.write(str(loss))
	loss_gen_file.write('\n')
loss_gen_file.close()

loss_dis_file = open('/content/drive/My Drive/3rd-year-project/forest-model/loss_dis.txt', 'w')
for loss in loss_dis:
	loss_dis_file.write(str(loss))
	loss_dis_file.write('\n')
loss_dis_file.close()

# %%
# initialization G2
learning_rate_G = 2e-5
learning_rate_D = 1e-5
train_global = False
continue_train = True

if train_global == False:
    generator_global = GlobalGenerator(3, 3)
    generator_global.load_state_dict(torch.load(global_model))
    generator = LocalEnhancer(3, 3, generator_global).to(device)
    generator_model_path = local_model
else:
    generator = GlobalGenerator(3, 3).to(device)
    generator_model_path = global_model

discriminator = MultiscaleDiscriminator(input_nc=6).to(device)

if continue_train:
    generator.load_state_dict(torch.load(generator_model_path))
    discriminator.load_state_dict(torch.load(discriminator_model_path))
elif train_global == False:
    discriminator.load_state_dict(torch.load(discriminator_model_path))

generator.train()
generator.to(device)
discriminator.train()
model = pix2pixHD(num_D=3, generator=generator, discriminator=discriminator, device=device).to(device)

optimizer_G = optim.Adam(generator.parameters(), lr=learning_rate_G)
optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate_D)

# %%
# local enhancer
# epoch trained: 150
num_epoch = 50
trace_freq = 10
loss_gen_cont, loss_dis_cont = train()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
import matplotlib.pyplot as plt

loss_gen += loss_gen_cont
loss_dis += loss_dis_cont

# save loss data into files
loss_gen_file = open('/content/drive/My Drive/3rd-year-project/forest-model/loss_gen.txt', 'w')
for loss in loss_gen:
	loss_gen_file.write(str(loss))
	loss_gen_file.write('\n')
loss_gen_file.close()

loss_dis_file = open('/content/drive/My Drive/3rd-year-project/forest-model/loss_dis.txt', 'w')
for loss in loss_dis:
	loss_dis_file.write(str(loss))
	loss_dis_file.write('\n')
loss_dis_file.close()

t = np.arange(1, len(loss_gen)+1)
loss_gen = np.array(loss_gen)
loss_dis = np.array(loss_dis)
fig, axs = plt.subplots()
axs.plot(t, loss_gen, label="generator loss")
axs.plot(t, loss_dis, label="discriminator loss")
axs.set_xlim(0, 150)
axs.set_xlabel('epochs')
axs.set_ylabel('loss for generator and discriminator')
axs.grid(True)

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

fig.tight_layout()
plt.show()
